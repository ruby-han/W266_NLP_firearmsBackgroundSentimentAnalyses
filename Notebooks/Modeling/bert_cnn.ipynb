# %% [markdown]
# ### Import Packages

# %%
#@title Imports

# !pip install pydot --quiet
# !pip install gensim==3.8.3 --quiet
# !pip install tensorflow-datasets --quiet
# !pip install -U tensorflow-text==2.8.2 --quiet
# !pip install transformers --quiet
# !pip install pydot --quiet
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.17.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
# Import packages
import pandas as pd
import numpy as np

from tensorflow import keras
import tensorflow as tf
from keras.layers import Embedding, Input, Dense, Lambda
from keras.models import Model
import keras.backend as K
import tensorflow_addons as tfa
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences

from google.colab import drive

from collections import Counter
import matplotlib.pyplot as plt
from nltk.util import ngrams

from transformers import BertTokenizer, TFBertModel, logging as hf_logging, TFDistilBertModel, DistilBertConfig, DistilBertTokenizerFast
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split

import random
import itertools

import sklearn as sk
import os
import nltk
from nltk.corpus import reuters
from nltk.data import find

import re
import gensim
import absl.logging
from datetime import datetime
from pytz import timezone

pd.set_option("display.max_rows", None, # display all rows
              "display.max_columns", None, # display all columns
              "display.max_colwidth", None, # expand column width
              "display.html.use_mathjax", False) # disable Latex style mathjax rendering

# %%
drive.mount('/drive') 
# %cd /drive/MyDrive/W266 Project/Colab Notebooks/Exploration
# !pwd
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# /drive/.shortcut-targets-by-id/1p1bDkEjmNKPzX456WZWBr8qtvPr6Pt5m/W266 Project/Colab Notebooks/Exploration
# /drive/.shortcut-targets-by-id/1p1bDkEjmNKPzX456WZWBr8qtvPr6Pt5m/W266 Project/Colab Notebooks/Exploration

# %% [markdown]
# # Model - TFBERT + DISTILBERT + BERT W/ CNN

# %%
final_train = pd.read_csv('../../data/transformed/final/train.csv').sample(frac = 1) # shuffle rows
final_test = pd.read_csv('../../data/transformed/final/test.csv').sample(frac = 1) # shuffle rows

# %%
# Reduce size of data for quick testing 
small_train = final_train.sample(n = 8000, random_state = 2)
small_test = final_test.sample(n = 2000, random_state = 2)

# Simulate Undersampling
# small_train_1 = final_train[final_train['violent'] == 1].sample(n = 5000, random_state = 2)
# small_train_0 = final_train[final_train['violent'] == 0].sample(n = 3000, random_state = 2)
# small_train = pd.concat([small_train_1, small_train_0], ignore_index=True, axis=0)

# repoint to avoid having to update code below
final_train = small_train
final_test = small_test

# %%
# quick check to make sure we see expected representation of 0 and 1
display(final_train['violent'].value_counts())
final_test['violent'].value_counts()
# Out:
# 0    7181
# 1     819
# Name: violent, dtype: int64
# 0    1794
# 1     206
# Name: violent, dtype: int64

# %%
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-cased', do_lower_case = False)

# bert_tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')

# %%
max_length = 128

x_train = bert_tokenizer(list(final_train['comment_text_transf']),
                         max_length = max_length,
                         truncation = True,
                         padding = 'max_length',
                         return_tensors = 'tf')
y_train = list(final_train['violent'])

# %%
x_test = bert_tokenizer(list(final_test['comment_text_transf'].apply(str)),
                         max_length = max_length,
                         truncation = True,
                         padding = 'max_length',
                         return_tensors = 'tf')
y_test = list(final_test['violent'])

# %%
hf_logging.set_verbosity_error()
tf.get_logger().setLevel('ERROR')
absl.logging.set_verbosity(absl.logging.ERROR)

def create_bert_cnn_model(hidden_size = 50, 
                          learning_rate = 0.00001,
                          num_filters = [100, 100, 50, 25],
                          kernel_sizes = [3, 5, 10, 20],
                          dropout = 0.1):

    bert_model = TFBertModel.from_pretrained('bert-base-cased')

    input_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='input_ids_layer')
    token_type_ids = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='token_type_ids_layer')
    attention_mask = tf.keras.layers.Input(shape=(max_length,), dtype=tf.int64, name='attention_mask_layer')
    
    # Dictionary of inputs
    bert_inputs = {'input_ids': input_ids,
                   'token_type_ids': token_type_ids,
                   'attention_mask': attention_mask} 
    
    bert_out = bert_model(input_ids)

    output_token = bert_out[0][:,1:-1]
    
    h = output_token 
    conv_layers_for_all_kernel_sizes = []
    for kernel_size, filters in zip(kernel_sizes, num_filters):
        conv_layer = keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, activation='relu')(h)
        conv_layer = keras.layers.GlobalMaxPooling1D()(conv_layer)
        conv_layers_for_all_kernel_sizes.append(conv_layer)

    h = keras.layers.concatenate(conv_layers_for_all_kernel_sizes, axis=1)
    h = keras.layers.Dropout(rate=dropout)(h)

    hidden = tf.keras.layers.Dense(hidden_size, activation='relu', name='hidden_layer')(h)

    classification = tf.keras.layers.Dense(1, activation='sigmoid',name='classification_layer')(hidden)

   # instantiate model
    classification_model = tf.keras.Model(inputs=[input_ids, 
                                                  token_type_ids, 
                                                  attention_mask], outputs=[classification])

    # compile model
    classification_model.compile(optimizer=tfa.optimizers.AdamW(learning_rate = learning_rate,
                                                                weight_decay = 0),
                            loss=tf.keras.losses.BinaryCrossentropy(from_logits=False), 
                            metrics=['Precision', 'Recall',
                                     tfa.metrics.F1Score(num_classes=1, name='f1_score',
                                     threshold=0.5, average='weighted'),
                                     'TrueNegatives', 'TruePositives', 
                                     'FalsePositives', 'FalseNegatives',
                                     'accuracy', 'AUC'
                                     ])
    
   
    ### END YOUR CODE
    
    return classification_model

# %%
plot_show = False
hidden_size_list = [50, 75]
dropout_list = [0.1]
learning_rate_list = [0.00001, 0.00002]
num_filters_list = [[100, 100, 50, 25], [200, 200, 100, 50]]
kernel_sizes_list = [[3, 5, 10, 20], [5, 10, 15, 30]]
batch_size_list = [16, 32]
epochs_list = [75, 100]

grid_list = [hidden_size_list, dropout_list, learning_rate_list, 
             num_filters_list, kernel_sizes_list, batch_size_list, epochs_list]
grid = list(itertools.product(*grid_list))
random.shuffle(grid)

for i in range(3):
  start_time = datetime.now(timezone('America/Chicago')).strftime('%Y%m%d-%H%M%S')
  bert_cnn_model = create_bert_cnn_model(hidden_size=grid[i][0],
                                         dropout=grid[i][1],
                                         learning_rate=grid[i][2],
                                         num_filters=grid[i][3],
                                         kernel_sizes=grid[i][4]
                                         )
  chkpt_path = f'checkpoint/bertCNNmodel_{i+1}_{start_time}/cp.ckpt'
  chkpt_dir = os.path.dirname(chkpt_path)

  print(f'''
  {i+1}. hidden_size={grid[i][0]} 
     dropout={grid[i][1]} 
     learning_rate={grid[i][2]} 
     num_filters={grid[i][3]}
     kernel_sizes={grid[i][4]}
     batch_size={grid[i][5]}
     epochs={grid[i][6]}
     checkpoint_path={chkpt_path} 
        ''') 
  if plot_show == True:
    bert_cnn_model.summary()
    display(keras.utils.plot_model(bert_cnn_model, show_shapes=True, dpi=90))
  
  es = EarlyStopping(monitor='val_f1_score', mode='max', verbose=1, patience=5, min_delta=0.02)
  mc = ModelCheckpoint(chkpt_path, monitor='val_f1_score', mode='max', 
                        save_best_only=True, save_weights_only=True)
  
  bert_cnn_model_history = bert_cnn_model.fit(
                                              [x_train.input_ids, 
                                              x_train.token_type_ids, 
                                              x_train.attention_mask], 
                                              np.array(y_train),   
                                              validation_data=(
                                              [x_test.input_ids, 
                                              x_test.token_type_ids, 
                                              x_test.attention_mask], 
                                              np.array(y_test)),    
                                              batch_size=grid[i][5], 
                                              epochs=grid[i][6],
                                              callbacks=[es, mc])
# Out:
#   1. hidden_size=50
#      dropout=0.1
#      learning_rate=1e-05
#      num_filters=[200, 200, 100, 50]
#      kernel_sizes=[5, 10, 15, 30]
#      batch_size=32
#      epochs=100
#      checkpoint_path=checkpoint/bertCNNmodel_1_20220720-223539/cp.ckpt
#
# Epoch 1/100
# 250/250 [==============================] - 263s 982ms/step - loss: 0.2070 - precision: 0.7815 - recall: 0.4017 - f1_score: 0.5306 - true_negatives: 7089.0000 - true_positives: 329.0000 - false_positives: 92.0000 - false_negatives: 490.0000 - accuracy: 0.9273 - auc: 0.8894 - val_loss: 0.2638 - val_precision: 0.4909 - val_recall: 0.7816 - val_f1_score: 0.6030 - val_true_negatives: 1627.0000 - val_true_positives: 161.0000 - val_false_positives: 167.0000 - val_false_negatives: 45.0000 - val_accuracy: 0.8940 - val_auc: 0.9443
# Epoch 2/100
# 250/250 [==============================] - 240s 962ms/step - loss: 0.0962 - precision: 0.8631 - recall: 0.7778 - f1_score: 0.8182 - true_negatives: 7080.0000 - true_positives: 637.0000 - false_positives: 101.0000 - false_negatives: 182.0000 - accuracy: 0.9646 - auc: 0.9774 - val_loss: 0.2211 - val_precision: 0.5544 - val_recall: 0.7670 - val_f1_score: 0.6436 - val_true_negatives: 1667.0000 - val_true_positives: 158.0000 - val_false_positives: 127.0000 - val_false_negatives: 48.0000 - val_accuracy: 0.9125 - val_auc: 0.9515
# Epoch 3/100
# 250/250 [==============================] - 241s 965ms/step - loss: 0.0546 - precision: 0.9306 - recall: 0.8840 - f1_score: 0.9067 - true_negatives: 7127.0000 - true_positives: 724.0000 - false_positives: 54.0000 - false_negatives: 95.0000 - accuracy: 0.9814 - auc: 0.9933 - val_loss: 0.2821 - val_precision: 0.5690 - val_recall: 0.8010 - val_f1_score: 0.6653 - val_true_negatives: 1669.0000 - val_true_positives: 165.0000 - val_false_positives: 125.0000 - val_false_negatives: 41.0000 - val_accuracy: 0.9170 - val_auc: 0.9464
# Epoch 4/100
# 250/250 [==============================] - 234s 937ms/step - loss: 0.0301 - precision: 0.9648 - recall: 0.9365 - f1_score: 0.9504 - true_negatives: 7153.0000 - true_positives: 767.0000 - false_positives: 28.0000 - false_negatives: 52.0000 - accuracy: 0.9900 - auc: 0.9983 - val_loss: 0.4102 - val_precision: 0.5240 - val_recall: 0.8495 - val_f1_score: 0.6481 - val_true_negatives: 1635.0000 - val_true_positives: 175.0000 - val_false_positives: 159.0000 - val_false_negatives: 31.0000 - val_accuracy: 0.9050 - val_auc: 0.9393
# Epoch 5/100
# 250/250 [==============================] - 234s 936ms/step - loss: 0.0130 - precision: 0.9827 - recall: 0.9719 - f1_score: 0.9773 - true_negatives: 7167.0000 - true_positives: 796.0000 - false_positives: 14.0000 - false_negatives: 23.0000 - accuracy: 0.9954 - auc: 0.9997 - val_loss: 0.5486 - val_precision: 0.5100 - val_recall: 0.8641 - val_f1_score: 0.6414 - val_true_negatives: 1623.0000 - val_true_positives: 178.0000 - val_false_positives: 171.0000 - val_false_negatives: 28.0000 - val_accuracy: 0.9005 - val_auc: 0.9326
# Epoch 6/100
# 250/250 [==============================] - 234s 935ms/step - loss: 0.0110 - precision: 0.9816 - recall: 0.9768 - f1_score: 0.9792 - true_negatives: 7166.0000 - true_positives: 800.0000 - false_positives: 15.0000 - false_negatives: 19.0000 - accuracy: 0.9958 - auc: 0.9998 - val_loss: 0.4104 - val_precision: 0.5907 - val_recall: 0.7427 - val_f1_score: 0.6581 - val_true_negatives: 1688.0000 - val_true_positives: 153.0000 - val_false_positives: 106.0000 - val_false_negatives: 53.0000 - val_accuracy: 0.9205 - val_auc: 0.9158
# Epoch 7/100
# 250/250 [==============================] - 234s 935ms/step - loss: 0.0093 - precision: 0.9865 - recall: 0.9841 - f1_score: 0.9853 - true_negatives: 7170.0000 - true_positives: 806.0000 - false_positives: 11.0000 - false_negatives: 13.0000 - accuracy: 0.9970 - auc: 0.9993 - val_loss: 0.4896 - val_precision: 0.5507 - val_recall: 0.7913 - val_f1_score: 0.6494 - val_true_negatives: 1661.0000 - val_true_positives: 163.0000 - val_false_positives: 133.0000 - val_false_negatives: 43.0000 - val_accuracy: 0.9120 - val_auc: 0.9123
# Epoch 8/100
# 250/250 [==============================] - 234s 935ms/step - loss: 0.0059 - precision: 0.9914 - recall: 0.9890 - f1_score: 0.9902 - true_negatives: 7174.0000 - true_positives: 810.0000 - false_positives: 7.0000 - false_negatives: 9.0000 - accuracy: 0.9980 - auc: 0.9999 - val_loss: 0.4420 - val_precision: 0.5939 - val_recall: 0.7524 - val_f1_score: 0.6638 - val_true_negatives: 1688.0000 - val_true_positives: 155.0000 - val_false_positives: 106.0000 - val_false_negatives: 51.0000 - val_accuracy: 0.9215 - val_auc: 0.9061
# Epoch 8: early stopping
#
#   2. hidden_size=50
#      dropout=0.1
#      learning_rate=2e-05
#      num_filters=[200, 200, 100, 50]
#      kernel_sizes=[5, 10, 15, 30]
#      batch_size=32
#      epochs=100
#      checkpoint_path=checkpoint/bertCNNmodel_2_20220720-230741/cp.ckpt
#
# Epoch 1/100
# 250/250 [==============================] - 257s 979ms/step - loss: 0.1949 - precision: 0.7621 - recall: 0.4811 - f1_score: 0.5898 - true_negatives: 7058.0000 - true_positives: 394.0000 - false_positives: 123.0000 - false_negatives: 425.0000 - accuracy: 0.9315 - auc: 0.9043 - val_loss: 0.1814 - val_precision: 0.6509 - val_recall: 0.6699 - val_f1_score: 0.6603 - val_true_negatives: 1720.0000 - val_true_positives: 138.0000 - val_false_positives: 74.0000 - val_false_negatives: 68.0000 - val_accuracy: 0.9290 - val_auc: 0.9433
# Epoch 2/100
# 250/250 [==============================] - 234s 936ms/step - loss: 0.0868 - precision: 0.8633 - recall: 0.8022 - f1_score: 0.8316 - true_negatives: 7077.0000 - true_positives: 657.0000 - false_positives: 104.0000 - false_negatives: 162.0000 - accuracy: 0.9668 - auc: 0.9817 - val_loss: 0.2201 - val_precision: 0.5411 - val_recall: 0.7670 - val_f1_score: 0.6345 - val_true_negatives: 1660.0000 - val_true_positives: 158.0000 - val_false_positives: 134.0000 - val_false_negatives: 48.0000 - val_accuracy: 0.9090 - val_auc: 0.9402
# Epoch 3/100
# 250/250 [==============================] - 234s 935ms/step - loss: 0.0430 - precision: 0.9427 - recall: 0.9048 - f1_score: 0.9234 - true_negatives: 7136.0000 - true_positives: 741.0000 - false_positives: 45.0000 - false_negatives: 78.0000 - accuracy: 0.9846 - auc: 0.9951 - val_loss: 0.3325 - val_precision: 0.4668 - val_recall: 0.8883 - val_f1_score: 0.6120 - val_true_negatives: 1585.0000 - val_true_positives: 183.0000 - val_false_positives: 209.0000 - val_false_negatives: 23.0000 - val_accuracy: 0.8840 - val_auc: 0.9461
# Epoch 4/100
# 250/250 [==============================] - 234s 935ms/step - loss: 0.0201 - precision: 0.9654 - recall: 0.9548 - f1_score: 0.9601 - true_negatives: 7153.0000 - true_positives: 782.0000 - false_positives: 28.0000 - false_negatives: 37.0000 - accuracy: 0.9919 - auc: 0.9993 - val_loss: 0.4087 - val_precision: 0.5632 - val_recall: 0.7573 - val_f1_score: 0.6460 - val_true_negatives: 1673.0000 - val_true_positives: 156.0000 - val_false_positives: 121.0000 - val_false_negatives: 50.0000 - val_accuracy: 0.9145 - val_auc: 0.9088
# Epoch 5/100
# 250/250 [==============================] - 234s 935ms/step - loss: 0.0111 - precision: 0.9829 - recall: 0.9829 - f1_score: 0.9829 - true_negatives: 7167.0000 - true_positives: 805.0000 - false_positives: 14.0000 - false_negatives: 14.0000 - accuracy: 0.9965 - auc: 0.9991 - val_loss: 0.5810 - val_precision: 0.4828 - val_recall: 0.8883 - val_f1_score: 0.6256 - val_true_negatives: 1598.0000 - val_true_positives: 183.0000 - val_false_positives: 196.0000 - val_false_negatives: 23.0000 - val_accuracy: 0.8905 - val_auc: 0.9353
# Epoch 6/100
# 250/250 [==============================] - 233s 934ms/step - loss: 0.0123 - precision: 0.9792 - recall: 0.9780 - f1_score: 0.9786 - true_negatives: 7164.0000 - true_positives: 801.0000 - false_positives: 17.0000 - false_negatives: 18.0000 - accuracy: 0.9956 - auc: 0.9991 - val_loss: 0.4128 - val_precision: 0.5571 - val_recall: 0.7573 - val_f1_score: 0.6420 - val_true_negatives: 1670.0000 - val_true_positives: 156.0000 - val_false_positives: 124.0000 - val_false_negatives: 50.0000 - val_accuracy: 0.9130 - val_auc: 0.9033
# Epoch 6: early stopping
#
#   3. hidden_size=50
#      dropout=0.1
#      learning_rate=1e-05
#      num_filters=[200, 200, 100, 50]
#      kernel_sizes=[5, 10, 15, 30]
#      batch_size=16
#      epochs=100
#      checkpoint_path=checkpoint/bertCNNmodel_3_20220720-233211/cp.ckpt
#
# Epoch 1/100
# 500/500 [==============================] - 266s 507ms/step - loss: 0.1916 - precision: 0.7636 - recall: 0.4615 - f1_score: 0.5753 - true_negatives: 7064.0000 - true_positives: 378.0000 - false_positives: 117.0000 - false_negatives: 441.0000 - accuracy: 0.9302 - auc: 0.9124 - val_loss: 0.2411 - val_precision: 0.4958 - val_recall: 0.8689 - val_f1_score: 0.6314 - val_true_negatives: 1612.0000 - val_true_positives: 179.0000 - val_false_positives: 182.0000 - val_false_negatives: 27.0000 - val_accuracy: 0.8955 - val_auc: 0.9495
# Epoch 2/100
# 500/500 [==============================] - 254s 508ms/step - loss: 0.0898 - precision: 0.8854 - recall: 0.7924 - f1_score: 0.8363 - true_negatives: 7097.0000 - true_positives: 649.0000 - false_positives: 84.0000 - false_negatives: 170.0000 - accuracy: 0.9682 - auc: 0.9795 - val_loss: 0.2240 - val_precision: 0.5312 - val_recall: 0.8252 - val_f1_score: 0.6464 - val_true_negatives: 1644.0000 - val_true_positives: 170.0000 - val_false_positives: 150.0000 - val_false_negatives: 36.0000 - val_accuracy: 0.9070 - val_auc: 0.9527
# Epoch 3/100
# 500/500 [==============================] - 245s 490ms/step - loss: 0.0453 - precision: 0.9350 - recall: 0.8962 - f1_score: 0.9152 - true_negatives: 7130.0000 - true_positives: 734.0000 - false_positives: 51.0000 - false_negatives: 85.0000 - accuracy: 0.9830 - auc: 0.9951 - val_loss: 0.3305 - val_precision: 0.5272 - val_recall: 0.8010 - val_f1_score: 0.6358 - val_true_negatives: 1646.0000 - val_true_positives: 165.0000 - val_false_positives: 148.0000 - val_false_negatives: 41.0000 - val_accuracy: 0.9055 - val_auc: 0.9404
# Epoch 4/100
# 500/500 [==============================] - 245s 489ms/step - loss: 0.0248 - precision: 0.9615 - recall: 0.9463 - f1_score: 0.9538 - true_negatives: 7150.0000 - true_positives: 775.0000 - false_positives: 31.0000 - false_negatives: 44.0000 - accuracy: 0.9906 - auc: 0.9983 - val_loss: 0.4590 - val_precision: 0.4377 - val_recall: 0.8350 - val_f1_score: 0.5743 - val_true_negatives: 1573.0000 - val_true_positives: 172.0000 - val_false_positives: 221.0000 - val_false_negatives: 34.0000 - val_accuracy: 0.8725 - val_auc: 0.9394
# Epoch 5/100
# 500/500 [==============================] - 244s 489ms/step - loss: 0.0081 - precision: 0.9878 - recall: 0.9866 - f1_score: 0.9872 - true_negatives: 7171.0000 - true_positives: 808.0000 - false_positives: 10.0000 - false_negatives: 11.0000 - accuracy: 0.9974 - auc: 0.9999 - val_loss: 0.4285 - val_precision: 0.5878 - val_recall: 0.6990 - val_f1_score: 0.6386 - val_true_negatives: 1693.0000 - val_true_positives: 144.0000 - val_false_positives: 101.0000 - val_false_negatives: 62.0000 - val_accuracy: 0.9185 - val_auc: 0.8821
# Epoch 6/100
# 500/500 [==============================] - 245s 489ms/step - loss: 0.0128 - precision: 0.9816 - recall: 0.9756 - f1_score: 0.9786 - true_negatives: 7166.0000 - true_positives: 799.0000 - false_positives: 15.0000 - false_negatives: 20.0000 - accuracy: 0.9956 - auc: 0.9996 - val_loss: 0.4194 - val_precision: 0.5347 - val_recall: 0.7864 - val_f1_score: 0.6365 - val_true_negatives: 1653.0000 - val_true_positives: 162.0000 - val_false_positives: 141.0000 - val_false_negatives: 44.0000 - val_accuracy: 0.9075 - val_auc: 0.9258
# Epoch 6: early stopping

# %%
chkpt_path = 'checkpoint/model_3_20220720-180757/cp.ckpt'
bert_cnn_model = create_bert_cnn_model(
    hidden_size=50,
    dropout=0.1,
    learning_rate=0.00001,
    num_filters=[100, 100, 50, 25],
    kernel_sizes=[3, 5, 10, 20]  
)
bert_cnn_model.load_weights(chkpt_path)
# Out:
#   File "<ipython-input-12-84eac60ed97e>", line 4
#     dropout=0.1
#            ^
# SyntaxError: invalid syntax

# %%
score = bert_cnn_model.evaluate([x_test.input_ids, 
                                 x_test.token_type_ids, 
                                 x_test.attention_mask], 
                                 np.array(y_test))

# %%
predictions = bert_cnn_model.predict([x_test.input_ids, 
                                      x_test.token_type_ids, 
                                      x_test.attention_mask])

# %%
predictions = pd.Series(np.rint(predictions).flatten(), dtype = int)
test_ids = pd.Series(final_test.index)
test_check = final_test.copy()
test_check = test_check.reset_index(drop = True)
test_check = pd.concat([test_check, predictions, test_ids], axis = 1)
test_check.rename(columns = {'violent': 'actual', 0: 'prediction', 1: 'id'}, inplace = True)
test_check.set_index('id', inplace = True)

# %%
wrong_predictions = test_check[test_check['actual'] != test_check['prediction']]
fp = wrong_predictions[wrong_predictions['prediction'] == 1]
fn = wrong_predictions[wrong_predictions['prediction'] == 0]

# %%
len(fp)

# %%
fp.head()
